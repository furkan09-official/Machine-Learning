# %% [markdown]
# <a href="https://colab.research.google.com/github/furkan09-official/Machine-Learning/blob/main/opencv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
#read an image
img = cv2.imread("/content/cat.jpeg")
img.shape
# Out:
# (298, 209, 3)

# %%
print(img)
# Out:
# [[[169 171 165]
#   [169 171 165]
#   [169 171 165]
#   ...
#   [188 188 188]
#   [190 190 190]
#   [188 188 188]]
#
#  [[169 171 165]
#   [169 171 165]
#   [169 171 165]
#   ...
#   [186 186 186]
#   [188 188 188]
#   [187 187 187]]
#
#  [[169 171 165]
#   [169 171 165]
#   [169 171 165]
#   ...
#   [182 182 182]
#   [184 184 184]
#   [184 184 184]]
#
#  ...
#
#  [[230 230 230]
#   [230 230 230]
#   [230 230 230]
#   ...
#   [218 218 218]
#   [218 218 218]
#   [218 218 218]]
#
#  [[236 236 236]
#   [236 236 236]
#   [236 236 236]
#   ...
#   [219 219 219]
#   [219 219 219]
#   [219 219 219]]
#
#  [[236 236 236]
#   [236 236 236]
#   [236 236 236]
#   ...
#   [219 219 219]
#   [219 219 219]
#   [219 219 219]]]

# %%
#showing the image
plt.imshow(img)

# %%
#convert into gray image
img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(img_gray)

# %%
img_gray.shape
# Out:
# (298, 209)
