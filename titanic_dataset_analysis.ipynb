# %% [markdown]
# <a href="https://colab.research.google.com/github/furkan09-official/Machine-Learning/blob/main/titanic_dataset_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv('/content/Titanic-Dataset.csv')
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                       Name     Sex   Age  \
# 476          477         0       2    Renouf, Mr. Peter Henry    male  34.0
# 298          299         1       1      Saalfeld, Mr. Adolphe    male   NaN
# 576          577         1       2       Garside, Miss. Ethel  female  34.0
# 499          500         0       3         Svensson, Mr. Olof    male  24.0
# 371          372         0       3  Wiklund, Mr. Jakob Alfred    male  18.0
#
#      SibSp  Parch   Ticket     Fare Cabin Embarked
# 476      1      0    31027  21.0000   NaN        S
# 298      0      0    19988  30.5000  C106        S
# 576      0      0   243880  13.0000   NaN        S
# 499      0      0   350035   7.7958   NaN        S
# 371      1      0  3101267   6.4958   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# count plot
sns.countplot(df['Survived'])
df['Survived'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
# pie chart
df['Survived'].value_counts().plot(kind = 'pie',autopct = '%2.f')
# Out:
# <Axes: ylabel='count'>

# %%
# displot
sns.displot(df['Age'])

# %%
sns.lineplot(x= df['Age'], y = df['Fare'])
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>
