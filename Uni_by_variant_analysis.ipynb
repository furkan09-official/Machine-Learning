# %% [markdown]
# <a href="https://colab.research.google.com/github/furkan09-official/Machine-Learning/blob/main/Uni_by_variant_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
titanic =pd.read_csv('/Titanic-Dataset.csv')
tips = sns.load_dataset('tips')
tips
# titanic
# performing the bi and multi varient analysis
# (1)scatter plot(numerical to numerical)
# sns.scatterplot(x = titanic['Pclass'] , y = titanic['Survived'],hue= titanic['Sex'])
# (2) Bar plot
# sns.barplot(x = titanic['Pclass'],y = titanic['Age'])
sns.scatterplot(x = tips['total_bill'], y = tips['tip'] , hue=tips['smoker'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
tips['time'].value_counts().plot(kind = 'pie',autopct = '%.2f')
# this result shows that the tips are more given in dinner
# Out:
# <Axes: ylabel='count'>

# %%
import matplotlib.pyplot as plt
# plt.hist(tips['total_bill'])
sns.histplot(tips['time'])
# Out:
# <Axes: xlabel='time', ylabel='Count'>

# %%
tips
sns.scatterplot(y = tips['total_bill'] , x = tips['size'],hue = tips['sex'])
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
# plt.hist(tips['sex'])
# sns.lineplot(x = tips['total_bill'],y = tips['tip'])
sns.boxplot(titanic['Fare'])
sns.boxplot(titanic['Age'])
# Out:
# <Axes: ylabel='Fare'>
