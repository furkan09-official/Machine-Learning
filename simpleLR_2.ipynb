# %% [markdown]
# <a href="https://colab.research.google.com/github/furkan09-official/Machine-Learning/blob/main/simpleLR_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#generate the linear data
x = np.random.rand(100,1)
y = 4 + 2 *x + np.random.rand(100,1)
plt.scatter(x , y)
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train , x_test ,y_train , y_test = train_test_split(x , y , test_size = 0.8 , random_state = 1)
x_train.shape
# Out:
# (20, 1)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)
y_pred
# Out:
# array([[5.96324453],
#        [4.91985509],
#        [4.81004073],
#        [4.71248403],
#        [5.54776281],
#        [5.90570524],
#        [5.40418941],
#        [5.6751867 ],
#        [5.39101899],
#        [5.67797006],
#        [5.19701442],
#        [5.49654798],
#        [5.03678263],
#        [6.15175336],
#        [5.35748835],
#        [5.57121998],
#        [4.49623094],
#        [5.63303082],
#        [4.99869422],
#        [6.46706898],
#        [6.32729519],
#        [4.7657854 ],
#        [5.55356531],
#        [6.01012236],
#        [4.52675831],
#        [5.23024125],
#        [5.7201719 ],
#        [5.05258251],
#        [4.81592936],
#        [4.48458998],
#        [5.93150988],
#        [5.89388503],
#        [6.30597321],
#        [6.13524626],
#        [6.33597951],
#        [5.5665939 ],
#        [6.32754901],
#        [5.5946009 ],
#        [5.28644351],
#        [5.19679551],
#        [6.06517799],
#        [5.6468011 ],
#        [5.90738222],
# ...

# %%
from sklearn.metrics import r2_score
r2_score(y_test , y_pred)
# Out:
# 0.8249791405865954

# %%
#draw the regression line
plt.scatter(x_test , y_test)
plt.plot(x_test , lr.predict(x_test) , c = 'r')
plt.show()

# %%
plt.scatter(x_train , y_train , c = 'b')
#make regression line
plt.plot(x_train , lr.predict(x_train) , c = 'r')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
